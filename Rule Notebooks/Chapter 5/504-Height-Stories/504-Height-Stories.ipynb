# %% [markdown]
# # Section 504 - BUILDING HEIGHT AND NUMBER OF STORIES

# %%
# %run 504.2-Mixed-Occupancy.ipynb
# Out:
# This section is considered: Passed
#
# No individual occupancy exceeded the height and number of story limits specified in this section for the applicable occupancies.

# %%
# %run 504.3-Height.ipynb
# Out:
#     <div style="max-height: 300px; overflow-y: scroll;">
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Occupancy Group</th>
#       <th>Sprinkler System</th>
#       <th>Construction Type</th>
#       <th>Subtype</th>
#       <th>Height Limit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>A, A-2, A-3, B, E, F, M, S, U</td>
#       <td>NS</td>
#       <td>Type I</td>
#       <td>A</td>
#       <td>UL</td>
#     </tr>
#     <tr>
#       <td>A, A-2, A-3, B, E, F, M, S, U</td>
#       <td>NS</td>
#       <td>Type I</td>
#       <td>B</td>
#       <td>160</td>
#     </tr>
#     <tr>
#       <td>A, A-2, A-3, B, E, F, M, S, U</td>
#       <td>NS</td>
#       <td>Type II</td>
#       <td>A</td>
#       <td>65</td>
#     </tr>
#     <tr>
#       <td>A, A-2, A-3, B, E, F, M, S, U</td>
#       <td>NS</td>
#       <td>Type II</td>
#       <td>B</td>
#       <td>55</td>
#     </tr>
#     <tr>
# ...

# %%
# %run 504.4-Stories.ipynb
# Out:
#     <div style="max-height: 300px; overflow-y: scroll;">
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Occupancy Group</th>
#       <th>Sprinkler System</th>
#       <th>Construction Type</th>
#       <th>Subtype</th>
#       <th>Height Limit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>A-1</td>
#       <td>NS</td>
#       <td>Type I</td>
#       <td>A</td>
#       <td>UL</td>
#     </tr>
#     <tr>
#       <td>A-1</td>
#       <td>NS</td>
#       <td>Type I</td>
#       <td>B</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <td>A-1</td>
#       <td>NS</td>
#       <td>Type II</td>
#       <td>A</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <td>A-1</td>
#       <td>NS</td>
#       <td>Type II</td>
#       <td>B</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>A-1</td>
#       <td>NS</td>
#       <td>Type III</td>
#       <td>A</td>
#       <td>3</td>
#     </tr>
#     <tr>
# ...

# %%
indv_height_result_504_2 = indv_height_result
indv_storey_result_504_2 = indv_storey_result
building_height_result_504_3 = building_height_result
building_storey_result_504_4 = story_num_result

# %%
# Check if all results are "Passed"
all_passed = "Passed"
failed_sections = []

if indv_storey_result_504_2 != "Passed":
    all_passed = "Failed"
    failed_sections.append("504.2 - Storey Result")

if indv_height_result_504_2 != "Passed":
    all_passed = "Failed"
    failed_sections.append("504.2 - Height Result")

if building_height_result_504_3 != "Passed":
    all_passed = "Failed"
    failed_sections.append("504.3 - Building Height Result")

if building_storey_result_504_4 != "Passed":
    all_passed = "Failed"
    failed_sections.append("504.4 - Building Storey Result")

# Print the overall result
if all_passed == "Passed":
    print(f"This section is considered: {all_passed} ")
else:
    print(f"This section is considered: {all_passed}")
    print("Sections that failed:", failed_sections)
    
print("This section does not have any direct requirements to verify. Please refer to the subsections for analysis results.")
# Out:
# This section is considered: Passed
# This section does not have any direct requirements to verify. Please refer to the subsections for analysis results.
