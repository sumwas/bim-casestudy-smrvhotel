# %% [markdown]
# # Section 601 - GENERAL
#
# ## Building Code
#
# ### TABLE 601 FIRE-RESISTANCE RATING REQUIREMENTS FOR BUILDING ELEMENTS (HOURS)

# %%
import pandas as pd

# Define the table data
data = {
    "BUILDING ELEMENT": [
        "Primary structural frame (see Section 202)",
        "Bearing walls Exteriore, f",
        "Bearing walls Interior",
        "Nonbearing walls and partitions Exterior",
        "Nonbearing walls and partitions Interiord",
        "Floor construction and associated secondary members (see Section 202)",
        "Roof construction and associated secondary members (see Section 202)"
    ],
    "TYPE I - A": ["3a", "3", "3a", "See Table 602", "0", "2", "11/2b"],
    "TYPE I - B": ["2a", "2", "2a", "0", "0", "2", "1b,c"],
    "TYPE II - A": ["1", "1", "1", "0", "0", "1", "1b,c"],
    "TYPE II - B": ["0", "0", "0", "0", "0", "0", "0c"],
    "TYPE III - A": ["1", "1", "1", "See Section 602.4.6", "0", "1", "1b,c"],
    "TYPE III - B": ["0", "0", "0", "0", "0", "0", "0"],
    "TYPE IV - HT": ["HT", "HT", "1/HT", "0", "0", "HT", "HT"],
    "TYPE V - A": ["1", "1", "1", "See Section 602.4.6", "0", "1", "1b,c"],
    "TYPE V - B": ["0", "0", "0", "0", "0", "0", "0"]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
df
# Out:
#                                     BUILDING ELEMENT     TYPE I - A  \
# 0         Primary structural frame (see Section 202)             3a
# 1                         Bearing walls Exteriore, f              3
# 2                             Bearing walls Interior             3a
# 3           Nonbearing walls and partitions Exterior  See Table 602
# 4          Nonbearing walls and partitions Interiord              0
# 5  Floor construction and associated secondary me...              2
# 6  Roof construction and associated secondary mem...          11/2b
#
#   TYPE I - B TYPE II - A TYPE II - B         TYPE III - A TYPE III - B  \
# 0         2a           1           0                    1            0
# 1          2           1           0                    1            0
# 2         2a           1           0                    1            0
# 3          0           0           0  See Section 602.4.6            0
# ...

# %% [markdown]
# **For SI**: 1 foot = 304.8 mm.
#
# a. **Roof supports**: Fire-resistance ratings of primary structural frame and bearing walls are permitted to be reduced by 1 hour where supporting a roof only.
#
# b. **Exceptions**: Except in Group F-1, H, M, and S-1 occupancies, fire protection of structural members shall not be required, including protection of roof framing and decking where every part of the roof construction is 20 feet or more above any floor immediately below. Fire-retardant-treated wood members shall be allowed to be used for such unprotected members.
#
# c. **Heavy timber**: In all occupancies, heavy timber shall be allowed where a 1-hour or less fire-resistance rating is required.
#
# d. **Minimum fire-resistance rating**: Not less than the fire-resistance rating required by other sections of this code.
#
# e. **Fire separation distance**: Not less than the fire-resistance rating based on fire separation distance (see Table 602).
#
# f. **Referenced rating**: Not less than the fire-resistance rating as referenced in Section 704.10.

# %% [markdown]
# This section is considered: Understood
#
# This section does not have any direct requirements to verify. Please refer to the subsections for analysis results.
